# %%
import pandas as pd
import numpy as np
import json
import ast

pd.set_option("display.max_columns", None)

# %%
with open("../data/raw/games.json", "r", encoding="utf-8") as f:
    steam_data = json.load(f)

# %%
steam = pd.DataFrame.from_dict(
    steam_data,
    orient="index"
)

# %%
steam.index.name = "appid"

steam = steam.reset_index()

# %%
steam.head()
# Out:
#      appid                                   name  release_date  required_age  \
# 0  2539430             Black Dragon Mage Playtest   Aug 1, 2023             0
# 1   496350  Supipara - Chapter 1 Spring Has Come!  Jul 29, 2016             0
# 2  1034400      Mystery Solitaire The Black Raven   May 6, 2019             0
# 3  3292190            버튜버 파라노이아 - Vtuber Paranoia  Oct 31, 2024             0
# 4  3631080                          Maze Quest VR  Apr 24, 2025             0
#
#    price  dlc_count                               detailed_description  \
# 0   0.00          0
# 1   5.24          0  Springtime, April: when the cherry trees come ...
# 2   4.99          0  Immerse yourself in the most beloved, mystical...
# 3   8.99          1  synopsis 'Hello, I'm Hiyoro, a new YouTuber!' ...
# 4   4.99          0  Its not just a Maze; its a Quest! Enter the ca...
#
#                                       about_the_game  \
# 0
# 1  Springtime, April: when the cherry trees come ...
# 2  Immerse yourself in the most beloved, mystical...
# 3  synopsis 'Hello, I'm Hiyoro, a new YouTuber!' ...
# 4  Its not just a Maze; its a Quest! Enter the ca...
#
#                                    short_description reviews  \
# 0
# 1  Spring has come, and our protagonist, Yukinari...
# 2      Discover an entrancing and spectacular world!
# 3  Yuha! I'll start the broadcast! Hakko's extrem...
# 4  Its not just a Maze; its a Quest! Enter the ca...
#
#                                         header_image  \
# 0  https://shared.akamai.steamstatic.com/store_it...
# 1  https://shared.akamai.steamstatic.com/store_it...
# 2  https://shared.akamai.steamstatic.com/store_it...
# 3  https://shared.akamai.steamstatic.com/store_it...
# 4  https://shared.akamai.steamstatic.com/store_it...
#
#                                        website  \
# 0
# 1               http://mangagamer.org/supipara
# 2        https://www.facebook.com/8FloorGames/
# 3
# 4  https://www.realityexpanded.com/books-games
#
#                             support_url                support_email  windows  \
# 0                                                                        True
# 1                 http://mangagamer.com       support@mangagamer.com     True
# 2  https://www.facebook.com/8FloorGames           support@8floor.net     True
# 3                                              yujingamesc@gmail.com     True
# 4       https://www.realityexpanded.com  support@realityexpanded.com     True
#
#      mac  linux  metacritic_score metacritic_url  achievements  \
# 0  False  False                 0                            0
# 1  False  False                 0                            0
# 2   True  False                 0                            0
# 3  False  False                 0                           19
# 4  False  False                 0                            0
#
#    recommendations                                              notes  \
# 0                0
# 1              231
# 2                0
# 3                0  The game includes the following elements. 1. G...
# 4                0
#
#                   supported_languages full_audio_languages  \
# 0                                  []                   []
# 1                           [English]                   []
# 2  [English, French, German, Russian]                   []
# 3                            [Korean]             [Korean]
# 4                           [English]            [English]
#
#                                             packages              developers  \
# 0                                                 []                      []
# 1  [{'title': 'Buy Supipara - Chapter 1 Spring Ha...                [minori]
# 2  [{'title': 'Buy Mystery Solitaire The Black Ra...           [Somer Games]
# 3  [{'title': 'Buy 버튜버 파라노이아 - Vtuber Paranoia', ...                 [유진게임즈]
# 4  [{'title': 'Buy Maze Quest VR', 'description':...  [Reality Expanded LLC]
#
#                publishers                                         categories  \
# 0                      []                                                 []
# 1            [MangaGamer]  [Single-player, Steam Trading Cards, Steam Clo...
# 2                [8floor]                    [Single-player, Family Sharing]
# 3                 [유진게임즈]  [Single-player, Steam Achievements, Family Sha...
# 4  [Reality Expanded LLC]  [Single-player, VR Only, Steam Leaderboards, F...
#
#                         genres  \
# 0                           []
# 1                  [Adventure]
# 2                     [Casual]
# 3  [Casual, Indie, Simulation]
# 4       [Action, Early Access]
#
#                                          screenshots movies  user_score  \
# 0  [https://shared.akamai.steamstatic.com/store_i...     []           0
# 1  [https://shared.akamai.steamstatic.com/store_i...     []           0
# 2  [https://shared.akamai.steamstatic.com/store_i...     []           0
# 3  [https://shared.akamai.steamstatic.com/store_i...     []           0
# 4  [https://shared.akamai.steamstatic.com/store_i...     []           0
#
#   score_rank  positive  negative estimated_owners  average_playtime_forever  \
# 0                    0         0            0 - 0                         0
# 1                  252         3        0 - 20000                         8
# 2                   21         3        0 - 20000                         0
# 3                    0         0        0 - 20000                         0
# 4                    0         0        0 - 20000                         0
#
#    average_playtime_2weeks  median_playtime_forever  median_playtime_2weeks  \
# 0                        0                        0                       0
# 1                        0                        8                       0
# 2                        0                        0                       0
# 3                        0                        0                       0
# 4                        0                        0                       0
#
#   discount  peak_ccu                                               tags
# 0        0         0                                                 []
# 1       65         0  {'Adventure': 27, 'Visual Novel': 19, 'Anime':...
# 2        0         0  {'Casual': 83, 'Card Game': 52, 'Solitaire': 4...
# 3        0         1                                                 []
# 4        0         0                                                 []

# %%
steam.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135043 entries, 0 to 135042
# Data columns (total 43 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   appid                     135043 non-null  object
#  1   name                      135043 non-null  object
#  2   release_date              135043 non-null  object
#  3   required_age              135043 non-null  int64
#  4   price                     135043 non-null  float64
#  5   dlc_count                 135043 non-null  int64
#  6   detailed_description      135043 non-null  object
#  7   about_the_game            135043 non-null  object
#  8   short_description         135043 non-null  object
#  9   reviews                   135043 non-null  object
#  10  header_image              135043 non-null  object
#  11  website                   135043 non-null  object
#  12  support_url               135043 non-null  object
#  13  support_email             135043 non-null  object
#  14  windows                   135043 non-null  bool
#  15  mac                       135043 non-null  bool
#  16  linux                     135043 non-null  bool
#  17  metacritic_score          135043 non-null  int64
#  18  metacritic_url            135043 non-null  object
#  19  achievements              135043 non-null  int64
#  20  recommendations           135043 non-null  int64
#  21  notes                     135043 non-null  object
#  22  supported_languages       135043 non-null  object
#  23  full_audio_languages      135043 non-null  object
#  24  packages                  135043 non-null  object
#  25  developers                135043 non-null  object
#  26  publishers                135043 non-null  object
#  27  categories                135043 non-null  object
#  28  genres                    135043 non-null  object
#  29  screenshots               135043 non-null  object
#  30  movies                    135043 non-null  object
#  31  user_score                135043 non-null  int64
#  32  score_rank                135043 non-null  object
#  33  positive                  135043 non-null  int64
#  34  negative                  135043 non-null  int64
#  35  estimated_owners          135043 non-null  object
#  36  average_playtime_forever  135043 non-null  int64
#  37  average_playtime_2weeks   135043 non-null  int64
#  38  median_playtime_forever   135043 non-null  int64
#  39  median_playtime_2weeks    135043 non-null  int64
#  40  discount                  135043 non-null  object
#  41  peak_ccu                  135043 non-null  int64
#  42  tags                      135043 non-null  object
# dtypes: bool(3), float64(1), int64(13), object(26)
# memory usage: 41.6+ MB

# %%
steam.columns = (
    steam.columns
    .str.lower()
    .str.replace(" ", "_")
)

# %%
steam.columns
# Out:
# Index(['appid', 'name', 'release_date', 'required_age', 'price', 'dlc_count',
#        'detailed_description', 'about_the_game', 'short_description',
#        'reviews', 'header_image', 'website', 'support_url', 'support_email',
#        'windows', 'mac', 'linux', 'metacritic_score', 'metacritic_url',
#        'achievements', 'recommendations', 'notes', 'supported_languages',
#        'full_audio_languages', 'packages', 'developers', 'publishers',
#        'categories', 'genres', 'screenshots', 'movies', 'user_score',
#        'score_rank', 'positive', 'negative', 'estimated_owners',
#        'average_playtime_forever', 'average_playtime_2weeks',
#        'median_playtime_forever', 'median_playtime_2weeks', 'discount',
#        'peak_ccu', 'tags'],
#       dtype='object')

# %%
remove_columns = [
    "header_image",
    "website",
    "support_url",
    "support_email",
    "detailed_description",
    "about_the_game",
    "short_description",
    "metacritic_url",
    "screenshots",
    "movies",
    "notes"
]

steam = steam.drop(
    columns=remove_columns,
    errors="ignore"
)

# %%
steam["release_date"].head()
# Out:
# 0     Aug 1, 2023
# 1    Jul 29, 2016
# 2     May 6, 2019
# 3    Oct 31, 2024
# 4    Apr 24, 2025
# Name: release_date, dtype: object

# %%
steam["release_date"] = pd.to_datetime(
    steam["release_date"],
    errors="coerce"
)

# %%
steam["release_year"] = (
    steam["release_date"]
    .dt.year
)

# %%
steam = steam[
    (steam["release_year"] >= 2018) &
    (steam["release_year"] <= 2024)
]

# %%
steam["price"].describe()
# Out:
# count    81517.000000
# mean         4.758614
# std         13.882386
# min          0.000000
# 25%          0.490000
# 50%          1.990000
# 75%          4.990000
# max        999.980000
# Name: price, dtype: float64

# %%
steam[
    steam["price"] > 200
]
# Out:
#           appid                                name release_date  \
# 31935   3013840                           True Love   2024-06-27
# 34463   1200520   Ascent Free-Roaming VR Experience   2019-12-27
# 41088   2504210  The Leverage Game Business Edition   2023-08-26
# 68275   2499620                   The Leverage Game   2023-08-25
# 77652   1105450               Aartform Curvy 3D 4.0   2020-01-20
# 102212   502570                       Houdini Indie   2018-10-10
#
#         required_age   price  dlc_count reviews  windows    mac  linux  \
# 31935              0  500.00          0             True  False  False
# 34463              0  999.00          0             True  False  False
# 41088              0  999.98          0             True  False  False
# 68275              0  999.98          0             True  False  False
# 77652              0  299.99          0             True  False  False
# 102212             0  269.99          0             True   True  False
#
#         metacritic_score  achievements  recommendations  supported_languages  \
# 31935                  0             0                0            [English]
# 34463                  0             0                0            [English]
# 41088                  0             0                0  [English, Japanese]
# 68275                  0             0                0  [English, Japanese]
# 77652                  0             0                0            [English]
# 102212                 0             0              235            [English]
#
#        full_audio_languages  \
# 31935                    []
# 34463             [English]
# 41088   [English, Japanese]
# 68275   [English, Japanese]
# 77652                    []
# 102212                   []
#
#                                                  packages      developers  \
# 31935   [{'title': 'Buy True Love', 'description': '',...         [A Guy]
# 34463   [{'title': 'Buy Ascent Free-Roaming VR Experie...       [Fury VR]
# 41088   [{'title': 'Buy The Leverage Game Business Edi...      [A&S Inc.]
# 68275   [{'title': 'Buy The Leverage Game', 'descripti...      [A&S Inc.]
# 77652   [{'title': 'Buy Aartform Curvy 3D 4.0', 'descr...  [Aartform Ltd]
# 102212  [{'title': 'Yearly Subscription', 'description...        [SideFX]
#
#                    publishers  \
# 31935    [Whoes heart broken]
# 34463   [Zenland Video Games]
# 41088              [A&S Inc.]
# 68275              [A&S Inc.]
# 77652          [Aartform Ltd]
# 102212               [SideFX]
#
#                                                categories  \
# 31935                     [Single-player, Family Sharing]
# 34463   [Single-player, Multi-player, Co-op, LAN Co-op...
# 41088   [Single-player, Multi-player, PvP, Family Shar...
# 68275   [Single-player, Multi-player, PvP, Online PvP,...
# 77652                                                  []
# 102212          [Partial Controller Support, Steam Cloud]
#
#                                                    genres  user_score  \
# 31935                  [Action, Adventure, Casual, Indie]           0
# 34463                                            [Action]           0
# 41088                                 [Indie, Simulation]           0
# 68275                                 [Indie, Simulation]           0
# 77652       [Animation & Modeling, Design & Illustration]           0
# 102212  [Animation & Modeling, Design & Illustration, ...           0
#
#        score_rank  positive  negative estimated_owners  \
# 31935                     3         1        0 - 20000
# 34463                     6         1        0 - 20000
# 41088                     0         0        0 - 20000
# 68275                     1         0        0 - 20000
# 77652                    10         2        0 - 20000
# 102212                  233        18        0 - 20000
#
#         average_playtime_forever  average_playtime_2weeks  \
# 31935                          0                        0
# 34463                          0                        0
# 41088                          0                        0
# 68275                          0                        0
# 77652                          0                        0
# 102212                       242                        0
#
#         median_playtime_forever  median_playtime_2weeks discount  peak_ccu  \
# 31935                         0                       0        0         0
# 34463                         0                       0        0         0
# 41088                         0                       0        0         0
# 68275                         0                       0        0         0
# 77652                         0                       0        0         0
# 102212                      242                       0        0        59
#
#                                                      tags  release_year
# 31935   {'Casual': 413, 'Action-Adventure': 387, 'Visu...          2024
# 34463   {'Action': 95, 'Hentai': 41, 'Nudity': 36, 'Se...          2019
# 41088                                                  []          2023
# 68275   {'Board Game': 48, 'Turn-Based Tactics': 42, '...          2023
# 77652   {'Design & Illustration': 22, 'Animation & Mod...          2020
# 102212  {'Animation & Modeling': 65, 'Game Development...          2018

# %%
steam.loc[
    steam["price"] > 200,
    "price"
] = np.nan

# %%
def owner_midpoint(value):
    if pd.isna(value):
        return np.nan
    
    value = value.replace(",", "")
    
    lower, upper = value.split("-")
    
    return (
        int(lower.strip()) +
        int(upper.strip())
    ) / 2

# %%
steam["estimated_players"] = (
    steam["estimated_owners"]
    .apply(owner_midpoint)
)

# %%
steam["total_reviews"] = (
    steam["positive"]
    +
    steam["negative"]
)

# %%
steam["review_score"] = np.where(
    steam["total_reviews"] > 0,
    steam["positive"] /
    steam["total_reviews"],
    np.nan
)

# %%
steam["genres"] = steam["genres"].apply(
    lambda x: x if isinstance(x, list)
    else []
)

# %%
steam.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 81517 entries, 0 to 134936
# Data columns (total 36 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   appid                     81517 non-null  object
#  1   name                      81517 non-null  object
#  2   release_date              81517 non-null  datetime64[ns]
#  3   required_age              81517 non-null  int64
#  4   price                     81511 non-null  float64
#  5   dlc_count                 81517 non-null  int64
#  6   reviews                   81517 non-null  object
#  7   windows                   81517 non-null  bool
#  8   mac                       81517 non-null  bool
#  9   linux                     81517 non-null  bool
#  10  metacritic_score          81517 non-null  int64
#  11  achievements              81517 non-null  int64
#  12  recommendations           81517 non-null  int64
#  13  supported_languages       81517 non-null  object
#  14  full_audio_languages      81517 non-null  object
#  15  packages                  81517 non-null  object
#  16  developers                81517 non-null  object
#  17  publishers                81517 non-null  object
#  18  categories                81517 non-null  object
#  19  genres                    81517 non-null  object
#  20  user_score                81517 non-null  int64
#  21  score_rank                81517 non-null  object
#  22  positive                  81517 non-null  int64
#  23  negative                  81517 non-null  int64
#  24  estimated_owners          81517 non-null  object
#  25  average_playtime_forever  81517 non-null  int64
#  26  average_playtime_2weeks   81517 non-null  int64
#  27  median_playtime_forever   81517 non-null  int64
#  28  median_playtime_2weeks    81517 non-null  int64
#  29  discount                  81517 non-null  object
#  30  peak_ccu                  81517 non-null  int64
#  31  tags                      81517 non-null  object
#  32  release_year              81517 non-null  int32
#  33  estimated_players         81517 non-null  float64
#  34  total_reviews             81517 non-null  int64
#  35  review_score              61234 non-null  float64
# dtypes: bool(3), datetime64[ns](1), float64(3), int32(1), int64(14), object(14)
# memory usage: 21.1+ MB

# %%
steam.isna().sum()
# Out:
# appid                           0
# name                            0
# release_date                    0
# required_age                    0
# price                           6
# dlc_count                       0
# reviews                         0
# windows                         0
# mac                             0
# linux                           0
# metacritic_score                0
# achievements                    0
# recommendations                 0
# supported_languages             0
# full_audio_languages            0
# packages                        0
# developers                      0
# publishers                      0
# categories                      0
# genres                          0
# user_score                      0
# score_rank                      0
# positive                        0
# negative                        0
# estimated_owners                0
# average_playtime_forever        0
# average_playtime_2weeks         0
# median_playtime_forever         0
# median_playtime_2weeks          0
# discount                        0
# peak_ccu                        0
# tags                            0
# release_year                    0
# estimated_players               0
# total_reviews                   0
# review_score                20283
# dtype: int64

# %%
missing = pd.DataFrame({
    "missing_count": steam.isna().sum(),
    "missing_percentage": (
        steam.isna().sum() / len(steam) * 100
    )
})

missing.sort_values(
    "missing_percentage",
    ascending=False
)
# Out:
#                           missing_count  missing_percentage
# review_score                      20283           24.881926
# price                                 6            0.007360
# median_playtime_forever               0            0.000000
# score_rank                            0            0.000000
# positive                              0            0.000000
# negative                              0            0.000000
# estimated_owners                      0            0.000000
# average_playtime_forever              0            0.000000
# average_playtime_2weeks               0            0.000000
# median_playtime_2weeks                0            0.000000
# genres                                0            0.000000
# discount                              0            0.000000
# peak_ccu                              0            0.000000
# tags                                  0            0.000000
# release_year                          0            0.000000
# estimated_players                     0            0.000000
# total_reviews                         0            0.000000
# user_score                            0            0.000000
# appid                                 0            0.000000
# name                                  0            0.000000
# linux                                 0            0.000000
# release_date                          0            0.000000
# required_age                          0            0.000000
# dlc_count                             0            0.000000
# reviews                               0            0.000000
# windows                               0            0.000000
# mac                                   0            0.000000
# metacritic_score                      0            0.000000
# publishers                            0            0.000000
# achievements                          0            0.000000
# recommendations                       0            0.000000
# supported_languages                   0            0.000000
# full_audio_languages                  0            0.000000
# packages                              0            0.000000
# developers                            0            0.000000
# categories                            0            0.000000

# %%
steam.to_csv(
    "../data/cleaned/steam_cleaned.csv",
    index=False
)
